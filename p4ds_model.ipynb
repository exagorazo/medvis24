# %%
import pandas as pd
#from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("p4ds_data.csv")
df
# Out:
#       A00_SEX  A01_AGE  A01_SMAM  A01_PACKYR  DMDRUG  A01_OBDIG1  A01_OBDIG2  \
# 0         0.0     53.0       0.0         3.5       0        28.0        0.91
# 1         0.0     47.0       8.0         8.0       0        15.9        0.83
# 2         1.0     43.0       0.0         0.0       0        33.8        0.90
# 3         1.0     62.0       0.0         0.0       0        33.1        0.94
# 4         1.0     41.0      40.0        40.0       0        34.2        0.89
# ...       ...      ...       ...         ...     ...         ...         ...
# 6932      1.0     62.0      10.0        15.0       0        27.3        0.89
# 6933      1.0     60.0       0.0         0.0       0        26.7        0.89
# 6934      1.0     62.0       0.0         0.0       0        39.5        0.96
# 6935      1.0     65.0       0.0         0.0       0        33.6        0.95
# 6936      1.0     59.0       0.0         0.0       0        39.0        1.01
#
# ...

# %%
df1 = df.drop(['A01_GLU120_TR', 'GLU_1h', 'GLU_2h'], axis=1)
df2 = df.drop(['A01_GLU60_TR', 'GLU_1h', 'GLU_2h'], axis=1)

# %%
df1
# Out:
#       A00_SEX  A01_AGE  A01_SMAM  A01_PACKYR  DMDRUG  A01_OBDIG1  A01_OBDIG2  \
# 0         0.0     53.0       0.0         3.5       0        28.0        0.91
# 1         0.0     47.0       8.0         8.0       0        15.9        0.83
# 2         1.0     43.0       0.0         0.0       0        33.8        0.90
# 3         1.0     62.0       0.0         0.0       0        33.1        0.94
# 4         1.0     41.0      40.0        40.0       0        34.2        0.89
# ...       ...      ...       ...         ...     ...         ...         ...
# 6932      1.0     62.0      10.0        15.0       0        27.3        0.89
# 6933      1.0     60.0       0.0         0.0       0        26.7        0.89
# 6934      1.0     62.0       0.0         0.0       0        39.5        0.96
# 6935      1.0     65.0       0.0         0.0       0        33.6        0.95
# 6936      1.0     59.0       0.0         0.0       0        39.0        1.01
#
# ...

# %%
df2
# Out:
#       A00_SEX  A01_AGE  A01_SMAM  A01_PACKYR  DMDRUG  A01_OBDIG1  A01_OBDIG2  \
# 0         0.0     53.0       0.0         3.5       0        28.0        0.91
# 1         0.0     47.0       8.0         8.0       0        15.9        0.83
# 2         1.0     43.0       0.0         0.0       0        33.8        0.90
# 3         1.0     62.0       0.0         0.0       0        33.1        0.94
# 4         1.0     41.0      40.0        40.0       0        34.2        0.89
# ...       ...      ...       ...         ...     ...         ...         ...
# 6932      1.0     62.0      10.0        15.0       0        27.3        0.89
# 6933      1.0     60.0       0.0         0.0       0        26.7        0.89
# 6934      1.0     62.0       0.0         0.0       0        39.5        0.96
# 6935      1.0     65.0       0.0         0.0       0        33.6        0.95
# 6936      1.0     59.0       0.0         0.0       0        39.0        1.01
#
# ...

# %%
#train_df1, test_df1 = train_test_split(df1, test_size=0.1, random_state=42)

# %%
#train_df2, test_df2 = train_test_split(df2, test_size=0.1, random_state=42)

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 46.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 23.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 48.2 MB/s eta 0:00:00
# ...

# %%
from pycaret.regression import *

# %%
import pickle
from sklearn.ensemble import GradientBoostingRegressor

# %%
#train_df1
# Out:
#       A00_SEX  A01_AGE  A01_SMAM  A01_PACKYR  DMDRUG  A01_OBDIG1  A01_OBDIG2  \
# 4553      0.0     49.0      20.0       20.00       0        25.7        0.93
# 6524      1.0     50.0       0.0        0.00       0        34.2        0.91
# 6507      1.0     60.0       0.0        0.00       0        37.1        0.98
# 5009      1.0     57.0       0.0        0.00       0        28.2        0.88
# 4647      0.0     42.0       3.0        2.25       0        16.4        0.83
# ...       ...      ...       ...         ...     ...         ...         ...
# 3772      0.0     58.0       0.0        0.00       0        25.4        0.93
# 5191      1.0     47.0       0.0        0.00       0        32.6        0.89
# 5226      1.0     52.0      10.0       15.00       0        27.2        0.87
# 5390      1.0     44.0       0.0        0.00       0        33.2        0.89
# 860       1.0     61.0       0.0        0.00       0        38.6        1.01
#
# ...

# %%
reg1 = setup(df1, target = 'A01_GLU60_TR', train_size = 0.9)
# Out:
# <style type="text/css">
# #T_129b2_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_129b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_129b2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_129b2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_129b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_129b2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_129b2_row0_col1" class="data row0 col1" >8641</td>
#     </tr>
#     <tr>
#       <th id="T_129b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_129b2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_129b2_row1_col1" class="data row1 col1" >A01_GLU60_TR</td>
#     </tr>
#     <tr>
#       <th id="T_129b2_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(sort = 'RMSE')
# Out:
# <style type="text/css">
# #T_7f749 th {
#   text-align: left;
# }
# ...

# %%
gbr1=create_model('gbr',cross_validation=True)
# Out:
# <style type="text/css">
# #T_758bb_row10_col0, #T_758bb_row10_col1, #T_758bb_row10_col2, #T_758bb_row10_col3, #T_758bb_row10_col4, #T_758bb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_758bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_758bb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_758bb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_758bb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_758bb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_758bb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_758bb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
gbr1
# Out:
# GradientBoostingRegressor(random_state=8641)

# %%
with open('glu1h_model.pkl', 'wb') as file:
    pickle.dump(gbr1, file)

# %%
# save_model(gbr1,'glu1h_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['A00_SEX', 'A01_AGE', 'A01_SMAM',
#                                               'A01_PACKYR', 'DMDRUG',
#                                               'A01_OBDIG1', 'A01_OBDIG2',
#                                               'A01_WEIGHT', 'BMI', 'A01_HBA1C',
#                                               'A01_GLU0_TR'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model',
#                   GradientBoostingRegressor(random_state=8641))]),
#  'glu1h_model.pkl')

# %%
reg2 = setup(df2, target = 'A01_GLU120_TR', train_size = 0.9)
# Out:
# <style type="text/css">
# #T_b0e2f_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b0e2f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0e2f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b0e2f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0e2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0e2f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b0e2f_row0_col1" class="data row0 col1" >6085</td>
#     </tr>
#     <tr>
#       <th id="T_b0e2f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0e2f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b0e2f_row1_col1" class="data row1 col1" >A01_GLU120_TR</td>
#     </tr>
#     <tr>
#       <th id="T_b0e2f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(sort = 'RMSE')
# Out:
# <style type="text/css">
# #T_4f1c7 th {
#   text-align: left;
# }
# ...

# %%
gbr2=create_model('gbr',cross_validation=True)
# Out:
# <style type="text/css">
# #T_dc5a4_row10_col0, #T_dc5a4_row10_col1, #T_dc5a4_row10_col2, #T_dc5a4_row10_col3, #T_dc5a4_row10_col4, #T_dc5a4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_dc5a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc5a4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_dc5a4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_dc5a4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_dc5a4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_dc5a4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_dc5a4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
with open('glu2h_model.pkl', 'wb') as file:
    pickle.dump(gbr2, file)

# %%
#save_model(gbr2,'glu2h_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['A00_SEX', 'A01_AGE', 'A01_SMAM',
#                                               'A01_PACKYR', 'DMDRUG',
#                                               'A01_OBDIG1', 'A01_OBDIG2',
#                                               'A01_WEIGHT', 'BMI', 'A01_HBA1C',
#                                               'A01_GLU0_TR'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model',
#                   GradientBoostingRegressor(random_state=6085))]),
#  'glu2h_model.pkl')
